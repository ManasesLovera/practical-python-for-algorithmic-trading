# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Download & export data tables

# %% [markdown]
# ### Download Microsoft OHLCV with `yfinance` library

# %%
import yfinance as yf

# %%
ticker = 'MSFT'
df_MSFT = yf.download(ticker, multi_level_index=False, auto_adjust=False, start='2010-01-01')
df_MSFT
# Out:
# [*********************100%***********************]  1 of 1 completed
#              Adj Close       Close        High         Low        Open  \
# Date
# 2010-01-04   23.173344   30.950001   31.100000   30.590000   30.620001
# 2010-01-05   23.180830   30.959999   31.100000   30.639999   30.850000
# 2010-01-06   23.038582   30.770000   31.080000   30.520000   30.879999
# 2010-01-07   22.798973   30.450001   30.700001   30.190001   30.629999
# 2010-01-08   22.956209   30.660000   30.879999   30.240000   30.280001
# ...                ...         ...         ...         ...         ...
# 2025-10-06  528.570007  528.570007  531.030029  518.200012  518.609985
# 2025-10-07  523.979980  523.979980  529.799988  521.440002  528.289978
# 2025-10-08  524.849976  524.849976  526.950012  523.090027  523.280029
# 2025-10-09  522.400024  522.400024  524.330017  517.400024  522.340027
# 2025-10-10  510.959991  510.959991  523.580017  509.630005  519.640015
#
#               Volume
# Date
# 2010-01-04  38409100
# 2010-01-05  49749600
# 2010-01-06  58182400
# 2010-01-07  50559700
# 2010-01-08  51197400
# ...              ...
# 2025-10-06  21388600
# 2025-10-07  14615200
# 2025-10-08  13363400
# 2025-10-09  18343600
# 2025-10-10  24065400
#
# [3968 rows x 6 columns]

# %% [markdown]
# ### Download any ticker

# %% [markdown]
# **Search for the ticker code**
#
# YFinance: https://finance.yahoo.com/
#
# - [x] Microsoft: MSFT
# - [ ] Bitcoin: ???

# %%
ticker = 'BTC-USD'
df_BTC = yf.download(ticker, multi_level_index=False, auto_adjust=False, start='2014-01-01')
df_BTC
# Out:
# [*********************100%***********************]  1 of 1 completed
#                 Adj Close          Close           High            Low  \
# Date
# 2014-09-17     457.334015     457.334015     468.174011     452.421997
# 2014-09-18     424.440002     424.440002     456.859985     413.104004
# 2014-09-19     394.795990     394.795990     427.834991     384.532013
# 2014-09-20     408.903992     408.903992     423.295990     389.882996
# 2014-09-21     398.821014     398.821014     412.425995     393.181000
# ...                   ...            ...            ...            ...
# 2025-10-08  123354.867188  123354.867188  124167.093750  121119.179688
# 2025-10-09  121705.585938  121705.585938  123739.343750  119812.031250
# 2025-10-10  113214.367188  113214.367188  122509.664062  104582.414062
# 2025-10-11  110807.882812  110807.882812  113429.726562  109760.562500
# 2025-10-13  114607.515625  114607.515625  115845.421875  114607.515625
#
#                      Open        Volume
# Date
# 2014-09-17     465.864014      21056800
# 2014-09-18     456.859985      34483200
# 2014-09-19     424.102997      37919700
# 2014-09-20     394.673004      36863600
# 2014-09-21     408.084991      26580100
# ...                   ...           ...
# 2025-10-08  121448.351562   65354305286
# 2025-10-09  123337.070312   74653009425
# 2025-10-10  121704.742188  153125018868
# 2025-10-11  113236.429688  110236934340
# 2025-10-13  115091.039062   91797323776
#
# [4044 rows x 6 columns]

# %% [markdown]
# ## Visualize the data with plotly
#
# https://plotly.com/python/candlestick-charts/

# %%
import plotly.graph_objects as go

# %%
df = df_MSFT
assert df is not None

fig = go.Figure(data=[go.Candlestick(x=df.index,
                open=df['Open'],
                high=df['High'],
                low=df['Low'],
                close=df['Close'])])

fig.show()

# %%
df = df_BTC
assert df is not None

fig = go.Figure(data=[go.Candlestick(x=df.index,
                open=df['Open'],
                high=df['High'],
                low=df['Low'],
                close=df['Close'])])

fig.show()

# %% [markdown]
# ## Export the data

# %% [markdown]
# ### Microsoft data

# %% [markdown]
# #### Drop `Adj Close`
#
# - To not confuse the `Close` and `Adj Close`

# %%
assert df_MSFT is not None
df_MSFT = df_MSFT.drop(columns='Adj Close')

# %% [markdown]
# #### To Excel

# %%
df_MSFT.to_excel('data/Microsoft_Stock_Price_Historical_Daily.xlsx')

# %% [markdown]
# #### To CSV
#
# - Less size in memory

# %%
df_MSFT.to_csv('data/Microsoft_Stock_Price_Historical_Daily.csv')

# %% [markdown]
# ### Bitcoin data altogether

# %% [markdown]
# #### Define ticker

# %%
ticker = 'BTC-USD'
ticker
# Out:
# 'BTC-USD'

# %% [markdown]
# #### Download OLHVC

# %%
df_ticker = yf.download(ticker, multi_level_index=False, auto_adjust=False, start='2014-09-17')
df_ticker
# Out:
# [*********************100%***********************]  1 of 1 completed
#                 Adj Close          Close           High            Low  \
# Date
# 2014-09-17     457.334015     457.334015     468.174011     452.421997
# 2014-09-18     424.440002     424.440002     456.859985     413.104004
# 2014-09-19     394.795990     394.795990     427.834991     384.532013
# 2014-09-20     408.903992     408.903992     423.295990     389.882996
# 2014-09-21     398.821014     398.821014     412.425995     393.181000
# ...                   ...            ...            ...            ...
# 2025-10-08  123354.867188  123354.867188  124167.093750  121119.179688
# 2025-10-09  121705.585938  121705.585938  123739.343750  119812.031250
# 2025-10-10  113214.367188  113214.367188  122509.664062  104582.414062
# 2025-10-11  110807.882812  110807.882812  113429.726562  109760.562500
# 2025-10-13  114639.281250  114639.281250  115845.421875  114639.281250
#
#                      Open        Volume
# Date
# 2014-09-17     465.864014      21056800
# 2014-09-18     456.859985      34483200
# 2014-09-19     424.102997      37919700
# 2014-09-20     394.673004      36863600
# 2014-09-21     408.084991      26580100
# ...                   ...           ...
# 2025-10-08  121448.351562   65354305286
# 2025-10-09  123337.070312   74653009425
# 2025-10-10  121704.742188  153125018868
# 2025-10-11  113236.429688  110236934340
# 2025-10-13  115091.039062   92657614848
#
# [4044 rows x 6 columns]

# %% [markdown]
# #### Create file path

# %%
file_path = f'data/{ticker}.xlsx'
file_path
# Out:
# 'data/BTC-USD.xlsx'

# %% [markdown]
# #### Export to Excel

# %%
df_ticker.to_excel(file_path)

# %% [markdown]
# #### Export to CSV

# %%
df_ticker.to_csv(f'data/{ticker}.csv')

# %% [markdown]
# #### Snippet

# %%
ticker = 'BTC-USD'
df_ticker = yf.download(ticker, multi_level_index=False, auto_adjust=False, start='2014-01-01')
df_ticker.to_excel(f'data/{ticker}.xlsx')
df_ticker.to_excel(f'data/{ticker}.csv')

# %% [markdown]
# ## [ ] Data Preprocessing

# %%
# Out:
#                   Open        High         Low       Close    Volume  \
# Date
# 2016-12-08   56.325228   56.582507   55.902560   56.058762  21220800
# 2016-12-09   56.214968   56.959234   56.169027   56.940857  27349400
# ...                ...         ...         ...         ...       ...
# 2023-03-14  256.750000  261.070007  255.860001  260.790009  33620300
# 2023-03-15  259.980011  266.480011  259.209991  265.440002  46028000
#
#             change_tomorrow change_tomorrow_direction
# Date
# 2016-12-08        -1.549143                      DOWN
# 2016-12-09        -0.321692                      DOWN
# ...                     ...                       ...
# 2023-03-14        -1.751806                      DOWN
# 2023-03-15        -3.895731                      DOWN
#
# [1576 rows x 7 columns]

# %% [markdown]
# ### Load the data

# %%
import pandas as pd

df_microsoft = pd.read_excel(
    'data/Microsoft_Stock_Price_Historical_Daily.xlsx',
    parse_dates=['Date'], index_col=0
)

df_microsoft
# Out:
#                   Open        High         Low       Close      Volume
# Date
# 1986-03-13    0.055241    0.063365    0.055241    0.060657  1031788800
# 1986-03-14    0.060657    0.063907    0.060657    0.062823   308160000
# ...                ...         ...         ...         ...         ...
# 2023-03-15  259.980011  266.480011  259.209991  265.440002    46028000
# 2023-03-16  265.209991  276.559998  263.279999  276.200012    54768800
#
# [9328 rows x 5 columns]

# %% [markdown]
# ### Filter the data

# %% [markdown]
# ![](src/Microsoft_x_LinkedIn.png)

# %%
df_microsoft_linkedin= df_microsoft.loc['2016-12-08':,:].copy()

# %% [markdown]
# ## Create new columns

# %% [markdown]
# ### Tomorrow's percentage change

# %%
df_microsoft_linkedin['change_tomorrow'] = df_microsoft_linkedin.Close.pct_change(-1) * 100 * -1

# %%
df_microsoft_linkedin
# Out:
#                   Open        High         Low       Close    Volume  \
# Date
# 2016-12-08   56.325228   56.582507   55.902560   56.058762  21220800
# 2016-12-09   56.214968   56.959234   56.169027   56.940857  27349400
# ...                ...         ...         ...         ...       ...
# 2023-03-15  259.980011  266.480011  259.209991  265.440002  46028000
# 2023-03-16  265.209991  276.559998  263.279999  276.200012  54768800
#
#             change_tomorrow
# Date
# 2016-12-08         1.549143
# 2016-12-09         0.321692
# ...                     ...
# 2023-03-15         3.895731
# 2023-03-16              NaN
#
# [1577 rows x 6 columns]

# %%
df_microsoft_linkedin = df_microsoft_linkedin.dropna().copy()

# %% [markdown]
# ### Did the stock go up or down?

# %%
import numpy as np

# %%
df_microsoft_linkedin['change_tomorrow_direction'] = np.where(
    df_microsoft_linkedin.change_tomorrow > 0, 'UP', 'DOWN')

# %%
df_microsoft_linkedin.change_tomorrow_direction.value_counts()
# Out:
# UP      849
# DOWN    727
# Name: change_tomorrow_direction, dtype: int64

# %%
df_microsoft_linkedin.Close.plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ## Export preprocessed DataFrame into an Excel

# %%
df_microsoft_linkedin.to_excel('data/Microsoft_LinkedIn_Processed.xlsx')
